# %% [markdown]
# # week 6
#
# ## goals:
# - meet with Dan & Ray to determine next steps
#
# ## todo
#
# - ~another sanity check - plot just the points that are inside MPAs (use the joined points table before aggregation)~
# - ~remember to check GFW for an MPA layer~
# - ~think about going back to boxes instead of points (might slow it down unnecessarily actually)~
# - ~make a list of mpas from Tim White's paper -- check fishing hours in those places~
#     - these don't have much
# - ~make a plot where the MPAs are colored by fishing hours?~
#
# - using just those mpas, do the join in a way that preserves mmsi
# - make a table keyed my mmsi, of effort in each mpa, plus effort in none?
#
#
# ## notes:
#
# - specifically try to answer:
#     - "you might want to just focus on MPAs that are beyond the continental shelves but we can talk about that."
#         - focus on high seas
#     - Should I include things like Ross Sea (which probably have a terrestrial component as well)?
#     - How do I use the post-2016 data? I'm in the google [permission?] group – can I make queries against an API?
#         - offline meeting with Dan to pull this data
#
# - GFW Data Training <- this is the google group to get added to
#
#
# - explicit theories about how they should behave and testing that
#
# - Ross Sea
# - PIPA
# - PMNM
# - south/central pacific ocean
# - pick out the 5 from Tim White's paper:
#     - PIPA - 2010 -- maybe this is 2015
#     - Pacific Remote Islands - 2009
#     - PMNM - yes but low fishing effort (3258 hours, 2016)
#     - Pitcairn Islands - yes but low (101 hours, 2016)
#     - Nazca-Desventuradas - yes but low (68 hours, 2016)
#
# Actual good ones:
# - Natural Park of the Coral Seas, 2014 555577562, further off the east coast of Australia
# - Marae Moana/Cook Islands, 2017 555624907 - maybe the best one - middle of the Pacific
# - French Austral Lands and Seas, 2019 555697868 - south-east of Africa
# - Arquipélago Submarino Do Meteor, 2016 555514087 - Atlantic ocean Y shaped area
# - Coral Sea, 2018 555556875 just off the east coast of Australia
# - Pacífico Mexicano Profundo, 2018 555624307 southwest Mexican coast
# - Palau National Marine Sanctuary, 2015, 555622118 oceania (near indonesia, phillippines)
#
#
# Can't use:
# - Phoenix Island - it's 2010
#
#
# A bunch of these at the top are coastal around Spain/France:
# - Espacio marino del Delta de l'Ebre-Illes Columbretes 2014
# - Espacio marino de la Costa da Morte 2014
# - Pertuis charentais - Rochebonne 2019

# %%
import numpy as np
import pandas
from datetime import datetime
import matplotlib.pyplot as plt
import os
import pywdpa
import geopandas
import contextily as ctx
from shapely import geometry
import pretty_html_table

pandas.set_option('display.max_columns', None)
pandas.set_option('display.max_rows', None)

# %%
# reads the downloaded WPDA polygon files
filenames = [
    "data/WDPA_WDOECM_wdpa_shp/WDPA_WDOECM_wdpa_shp0/WDPA_WDOECM_wdpa_shp-polygons.shp",
    "data/WDPA_WDOECM_wdpa_shp/WDPA_WDOECM_wdpa_shp1/WDPA_WDOECM_wdpa_shp-polygons.shp",
    "data/WDPA_WDOECM_wdpa_shp/WDPA_WDOECM_wdpa_shp2/WDPA_WDOECM_wdpa_shp-polygons.shp",
]
protected_areas = []
counted = 0
for filename in filenames:
    print(f'\r{counted}/{len(filenames)} {filename}', end='')
    protected_areas.append(geopandas.read_file(filename))
    counted += 1
    
protected_areas = pandas.concat(protected_areas)
# filters for marine only (may want to change this to 1 or 2 (2 is marine only, 1 is mixed, 0 is terrestrial))
mpas = protected_areas[protected_areas["MARINE"] == "2"]
# delete the larger table - it's like 3 GiB and not needed past this point
del(protected_areas)
# Out:
# 2/3 data/WDPA_WDOECM_wdpa_shp/WDPA_WDOECM_wdpa_shp2/WDPA_WDOECM_wdpa_shp-polygons.shp

# %%
## Load the fishing hours data (this is kinda slow)
filenames = os.listdir('data/daily_csvs')

# this might be faster but the status printout is nice:
# points = pandas.concat([geopandas.read_file('data/daily_csvs/' + filename) for filename in filenames])

counted = 0
points = []
for filename in filenames:
    print(f'\r {filename} {counted}/{len(filenames)}', end='')
    points.append(pandas.read_csv('data/daily_csvs/' + filename,
                                      dtype={'lat_bin': 'int16',
                                             'lon_bin': 'int16',
                                             'mmsi': 'int32',
                                             'fishing_hours': 'float32'},
                                 parse_dates=['date']))
    counted += 1
points = pandas.concat(points) # deliberately overwriting points
# Out:
#  2013-12-20.csv 1826/1827

# %%
## Aggregate the points and bin them
def compute_box(row, width=0.1):
    x = float(row['lon_bin'] * width)
    y = float(row['lat_bin'] * width)
    return geometry.box(x, y, x+width, y+width)

## Aggregate the points and bin them
points_aggregate = points.groupby(['lat_bin', 'lon_bin']).aggregate({'lat_bin': 'first', 'lon_bin': 'first', 'fishing_hours': 'sum'})
points_aggregate['geometry'] = points_aggregate.apply(compute_box, axis=1)
geopoints = geopandas.GeoDataFrame(points_aggregate, geometry=points_aggregate['geometry']).set_crs(epsg=4326)

# %%
# Produce ranked list of mpas by amount of effort inside their borders
# q - should we join by id or something first?

joined_points = geopandas.sjoin(geopoints, mpas, op='within')

# %%
## Plot
ax = joined_points.plot(column='fishing_hours', figsize=(20, 30), markersize=1, cmap='Blues', scheme='quantiles', legend=True)

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

ax = world.plot(
    color='white', edgecolor='black', ax=ax, )

LINEWIDTH = 0.5
mpas.plot(ax=ax, color='None', edgecolor='red', linewidth=LINEWIDTH, alpha=0.5)

plt.title('fishing hours inside mpas 2012-2016 in 0.1 degree aggregate')
# Out:
# Text(0.5, 1.0, 'fishing hours inside mpas 2012-2016 in 0.1 degree aggregate')

# %%
def string_join(strings):
    base = strings.iloc[0] if strings.any() else ''
    for s in strings[1:]:
        base = base if s in base else base + '|' + s
    return base


joined_points_aggregate = joined_points.groupby(['WDPAID'], as_index=False).aggregate({
    'NAME': string_join,
    'fishing_hours': 'sum',
    'STATUS_YR': 'first',
    'REP_M_AREA': 'sum',
    'REP_AREA': 'sum',
    'NO_TAKE': string_join,
})

sorted_mpas = joined_points_aggregate.sort_values("fishing_hours", ascending=False)

# %%
## Filter by year, fishing hours, and REP_AREA
mpas_ = sorted_mpas[sorted_mpas['STATUS_YR'] >= 2014]
mpas_ = mpas_[mpas_['STATUS_YR'] < 2020]

duplicates = [
    1195, 1203, 1418, 1419, 1420, 1421, 1422, 1423, 1424, 1425, 1426, 1202, 1505, 1200, 1198,
    1485, 1199, 1243, 1246, 1245, 996, 993, 1241, 997, 980, 987, 994, 1240, 1003, 999, 992, 
    562, 561, 563, 398, 395, 564, 558, 614
]
for dup in duplicates:
    try:
        mpas_ = mpas_.drop(dup)
    except:
        pass
    
mpas_ = mpas_[mpas_['REP_AREA'] > 100000]
#mpas_ = mpas_[mpas_['REP_M_AREA'] > 10000]

    
mpas_ = mpas_[mpas_['fishing_hours'] > 5000]
print(mpas_.info())
mpas_
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 620 to 568
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   WDPAID         26 non-null     float64
#  1   NAME           26 non-null     object
#  2   fishing_hours  26 non-null     float32
#  3   STATUS_YR      26 non-null     int64
#  4   REP_M_AREA     26 non-null     float64
#  5   REP_AREA       26 non-null     float64
#  6   NO_TAKE        26 non-null     object
# dtypes: float32(1), float64(3), int64(1), object(2)
# memory usage: 1.5+ KB
# None
#           WDPAID                                               NAME  \
# 620  555643633.0        Mers Celtiques - Talus du golfe de Gascogne
# 216  555539414.0                    Pertuis charentais - Rochebonne
# 511  555593060.0  Espacio marino del Delta de l'Ebre-Illes Colum...
# 576  555624872.0                                 Southern North Sea
# 429  555577562.0                      Natural Park of the Coral Sea
# 486  555589788.0          Estuaire De La Gironde Et Mer Des Pertuis
# 582  555624907.0  Marae Moana (Cook Islands Marine Park)|Marine ...
# 574  555624866.0                     Inner Hebrides and the Minches
# 641  555697868.0                      French Austral Lands and Seas
# 518  555596226.0  Corredor De Migracion De Cetaceos Del Mediterr...
# 604  555638666.0         Sylter Außenriff - Östliche Deutsche Bucht
# 575  555624871.0  Bristol Channel Approaches / Dynesfeydd Mor Ha...
# 117  555514087.0                    Arquipélago Submarino Do Meteor
# 459  555583053.0                         Faroe-Shetland Sponge Belt
# 642  555703191.0                                   West of Scotland
# 288  555556875.0                                          Coral Sea
# 655  555704263.0        Scott Islands Marine National Widllife Area
# 538  555622118.0                    Palau National Marine Sanctuary
# 456  555583050.0                                  North-west Orkney
# 572  555624861.0          West Wales Marine / Gorllewin Cymru Forol
# 556  555624307.0                         Pacífico Mexicano Profundo
# 637  555691643.0                            South West Deeps (East)
# 615  555643568.0                                            Yaganes
# 301  555556896.0                                     Oceanic Shoals
# 570  555624810.0              Ross Sea Region Marine Protected Area
# 568  555624642.0                    Hoburgs bank och Midsjöbankarna
#
#      fishing_hours  STATUS_YR    REP_M_AREA      REP_AREA        NO_TAKE
# 620  645055.500000       2018  0.000000e+00  5.166802e+07   Not Reported
# 216  234618.265625       2019  0.000000e+00  5.325177e+05   Not Reported
# 511  214009.687500       2014  0.000000e+00  5.500423e+05   Not Reported
# 576  174998.218750       2017  1.464487e+07  1.464487e+07   Not Reported
# 429  160425.421875       2014  7.535383e+09  7.535412e+09           Part
# 486  153670.875000       2015  0.000000e+00  2.470000e+05   Not Reported
# 582  121085.046875       2017  2.027340e+10  2.027340e+10           None
# 574  118529.585938       2017  1.091227e+06  1.091227e+06   Not Reported
# 641   76608.054688       2019  0.000000e+00  1.572729e+09   Not Reported
# 518   72807.351562       2018  0.000000e+00  1.682753e+07   Not Reported
# 604   49719.261719       2017  0.000000e+00  2.969590e+05   Not Reported
# 575   38783.378906       2017  2.574440e+05  2.574440e+05   Not Reported
# 117   27355.818359       2016  0.000000e+00  1.282904e+08   Not Reported
# 459   20854.046875       2014  2.533440e+05  2.533440e+05   Not Reported
# 642   18991.986328       2019  5.569021e+07  5.569021e+07   Not Reported
# 288   18910.341797       2018  7.644338e+08  7.644338e+08  Part|None|All
# 655   17299.716797       2018  1.099212e+06  1.099212e+06   Not Reported
# 538   15971.932617       2015  5.779196e+08  5.779196e+08   Not Reported
# 456   13561.856445       2014  1.876950e+05  1.876950e+05   Not Reported
# 572   12485.447266       2017  4.130560e+05  4.130560e+05   Not Reported
# 556    9777.407227       2016  2.174586e+08  2.174586e+08   Not Reported
# 637    8566.000977       2019  0.000000e+00  1.815471e+05   Not Reported
# 615    5816.746094       2018  9.753345e+05  9.753345e+05   Not Reported
# 301    5633.418457       2018  7.048215e+06  7.048215e+06      None|Part
# 570    5421.999512       2017  6.777208e+07  6.777208e+07            All
# 568    5116.364258       2016  0.000000e+00  9.144667e+05   Not Reported

# %%
reprint = True
if reprint:
    f = open("5000_fishing_hours_100000_km.html", "w")
    f.write(pretty_html_table.build_table(mpas_, 'blue_light'))
    f.close()

# %%
## redo the join using only the interesting mpas
wdpaids = mpas_['WDPAID']
mpas_in_list = mpas[mpas['WDPAID'].isin(wdpaids)]

joined_points_in_list = geopandas.sjoin(geopoints, mpas_in_list, op='intersects')

# %%
m_ = mpas_in_list.merge(mpas_, on='WDPAID').sort_values("fishing_hours", ascending=False)

# %%
## Plot
#ax = joined_points_in_list.plot(column='fishing_hours', figsize=(20, 30), markersize=1, cmap='Blues', scheme='quantiles', legend=True)

world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

ax = world.plot(
    color='white', edgecolor='black', figsize=(20, 30))

LINEWIDTH = 0.5
m_.plot(ax=ax, column='fishing_hours', edgecolor='red', linewidth=LINEWIDTH, scheme='quantiles', cmap='Blues', legend=True)

plt.title('mpas with >=5,000 fishing hours 2012-2016, >=100,000 km^2 that closed 2014-2019')
# Out:
# Text(0.5, 1.0, 'mpas with >=5,000 fishing hours 2012-2016, >=100,000 km^2 that closed 2014-2019')

# %%
palau = mpas[mpas['WDPAID'] == 555622118.0]

# %%
NUM_POINTS = 1000000
print('sampling... ', end='')
points_ = points#points.sample(NUM_POINTS)
print('done.')
print('computing boxes... ', end='')
points_['geometry'] = points_.apply(compute_box, axis=1)
print('done.')
geopoints_raw = geopandas.GeoDataFrame(points_, geometry=points_['geometry']).set_crs(epsg=4326)
# Out:
# sampling... done.
# computing boxes... done.

# %%
print('running sjoin... ', end='')
palau_points = geopandas.sjoin(geopoints_raw, palau, op='within')
print('done.')
print(palau_points.info())
# Out:
# running sjoin...

# %%
palau_points.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 74 entries, 10780 to 8115
# Data columns (total 37 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           74 non-null     datetime64[ns]
#  1   lat_bin        74 non-null     int16
#  2   lon_bin        74 non-null     int16
#  3   mmsi           74 non-null     int32
#  4   fishing_hours  74 non-null     float32
#  5   geometry       74 non-null     geometry
#  6   index_right    74 non-null     int64
#  7   WDPAID         74 non-null     float64
#  8   WDPA_PID       74 non-null     object
#  9   PA_DEF         74 non-null     object
#  10  NAME           74 non-null     object
#  11  ORIG_NAME      74 non-null     object
#  12  DESIG          74 non-null     object
#  13  DESIG_ENG      74 non-null     object
#  14  DESIG_TYPE     74 non-null     object
#  15  IUCN_CAT       74 non-null     object
#  16  INT_CRIT       74 non-null     object
#  17  MARINE         74 non-null     object
#  18  REP_M_AREA     74 non-null     float64
#  19  GIS_M_AREA     74 non-null     float64
#  20  REP_AREA       74 non-null     float64
#  21  GIS_AREA       74 non-null     float64
#  22  NO_TAKE        74 non-null     object
#  23  NO_TK_AREA     74 non-null     float64
#  24  STATUS         74 non-null     object
#  25  STATUS_YR      74 non-null     int64
#  26  GOV_TYPE       74 non-null     object
#  27  OWN_TYPE       74 non-null     object
#  28  MANG_AUTH      74 non-null     object
#  29  MANG_PLAN      74 non-null     object
#  30  VERIF          74 non-null     object
#  31  METADATAID     74 non-null     int64
#  32  SUB_LOC        74 non-null     object
#  33  PARENT_ISO     74 non-null     object
#  34  ISO3           74 non-null     object
#  35  SUPP_INFO      74 non-null     object
#  36  CONS_OBJ       74 non-null     object
# dtypes: datetime64[ns](1), float32(1), float64(6), geometry(1), int16(2), int32(1), int64(3), object(22)
# memory usage: 20.5+ KB

# %%
points_of_palau_ships = geopandas.GeoDataFrame(points_[points_['mmsi'].isin(palau_points['mmsi'])])

# %%
## Plot
ax = palau_points.plot(column='fishing_hours', figsize=(20, 30), cmap='Blues', scheme='quantiles', legend=True)


world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

world.plot(color='white', edgecolor='black', ax=ax, )
points_of_palau_ships.plot(column='fishing_hours', cmap='Reds', scheme='quantiles', ax=ax)

LINEWIDTH = 0.5
palau.plot(ax=ax, color='None', edgecolor='red', linewidth=LINEWIDTH, alpha=0.5)

plt.title('fishing hours inside mpas 2012-2016 in 0.1 degree aggregate')
# Out:
# Text(0.5, 1.0, 'fishing hours inside mpas 2012-2016 in 0.1 degree aggregate')
