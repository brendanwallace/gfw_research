# %% [markdown]
# # week 4
# ## goals:
# - use the API code
# - input the actual boundaries of the MPAs
#
# ### largest MPAs:
# 1. Marae Moana (Cook Islands) WPAID = 555624907
# 2. Ross Sea Region (Ross Sea)
# 3. Papahanaumokuakea Marine National Monument (PMNM) [177, -160], [19, 32]
# 4. Natural Park of the Coral Sea
# 5. Pacific Remote Islands (expanded) 400011
# 6. Coral Sea Marine Park
# 7. French Southern Territories Marine Reserve
# 8. Phoenix Islands wdpaid: 309888
# 9. Stellar Sea Lion Protection Areas (just Aleutian Islands 2015)

# %%
import numpy as np
import pandas as pd
from datetime import datetime
import matplotlib as plt
import os
import pywdpa
import geopandas as gpd

os.environ["WDPA_KEY"]="69f8f442fca6ea0165e8fde7cca64624"

# %%
pywdpa.get_wdpa("NZL")

# %%
pa_0 = gpd.read_file("data/shapefiles/polygons0.shp")
pa_1 = gpd.read_file("data/shapefiles/polygons1.shp")
pa_2 = gpd.read_file("data/shapefiles/polygons2.shp")

# %%
pa_ = pd.concat([pa_0, pa_1, pa_2])

# %%
pa_[pa_["WDPA_PID"] == "3098888"]
# Out:
# Empty GeoDataFrame
# Columns: [WDPAID, WDPA_PID, PA_DEF, NAME, ORIG_NAME, DESIG, DESIG_ENG, DESIG_TYPE, IUCN_CAT, INT_CRIT, MARINE, REP_M_AREA, GIS_M_AREA, REP_AREA, GIS_AREA, NO_TAKE, NO_TK_AREA, STATUS, STATUS_YR, GOV_TYPE, OWN_TYPE, MANG_AUTH, MANG_PLAN, VERIF, METADATAID, SUB_LOC, PARENT_ISO, ISO3, SUPP_INFO, CONS_OBJ, geometry]
# Index: []
#
# [0 rows x 31 columns]

# %%
pa_.head()
# Out:
#      WDPAID WDPA_PID PA_DEF                                             NAME  \
# 0  163583.0   163583      1                        Nsg Heidegebiet Steinfurt
# 1  163588.0   163588      1                             Heiden Im Langen Tal
# 2  163589.0   163589      1  Heiden In Lonsee Und Amstetten (12 Teilgebiete)
# 3  163590.0   163590      1                                  Nsg Heiderhardt
# 4  163591.0   163591      1                                     Nsg Heidesee
#
#                                          ORIG_NAME              DESIG  \
# 0                        Nsg Heidegebiet Steinfurt  Naturschutzgebiet
# 1                             Heiden Im Langen Tal  Naturschutzgebiet
# 2  Heiden In Lonsee Und Amstetten (12 Teilgebiete)  Naturschutzgebiet
# 3                                  Nsg Heiderhardt  Naturschutzgebiet
# 4                                     Nsg Heidesee  Naturschutzgebiet
#
#         DESIG_ENG DESIG_TYPE IUCN_CAT        INT_CRIT  ...     MANG_AUTH  \
# ...

# %%
pa_NZL = gpd.read_file("pa_NZL.shp")

# %%
# Out:
#    wdpa_id                                            pa_name ctry_iso3  \
# 0     1563  Te Hauturu-o-Toi / Little Barrier Island (Gift...       NZL
# 1     1590                                          Pukeamaru       NZL
# 2     1601                                          Maurihoro       NZL
# 3     1618                                     Arapawa Island       NZL
# 4     1949                        Red Mercury Island (Whakau)       NZL
#
#   is_marine            type iucn_cat  \
# 0     False  Nature Reserve       Ia
# 1     False  Scenic Reserve      III
# 2     False  Scenic Reserve      III
# 3     False  Scenic Reserve      III
# 4      True  Scenic Reserve      III
#
#                                             geometry
# 0  POLYGON ((175.05200 -36.21900, 175.04800 -36.1...
# 1  POLYGON ((178.24300 -37.67400, 178.20300 -37.6...
# 2  POLYGON ((175.86300 -37.69200, 175.87100 -37.7...
# 3  POLYGON ((174.33100 -41.20500, 174.33500 -41.1...
# ...

# %%
for i in range(pa_NZL.shape[0]):
# Out:
# 6871

# %%
nzl = pa_NZL.to_numpy()

# %%
for row in nzl:
    print(row[0])
# Out:
# 1563
# 1590
# 1601
# 1618
# 1949
# 1957
# 1958
# 1964
# 1965
# 4141
# 10465
# 10466
# 10468
# 10480
# 10483
# 10498
# 10510
# 10511
# 10514
# 26630
# 26636
# 26639
# 26640
# 26642
# 26643
# 68803
# 68808
# 68835
# 68848
# 68850
# 68851
# 71003
# 71004
# 143089
# 143090
# 143091
# 143093
# 143095
# 143097
# 143103
# 300328
# 300329
# 300330
# 303975
# 303976
# 303977
# 303978
# 303979
# 303980
# 303981
# 303982
# 303984
# 303985
# 303986
# 303987
# 303988
# 303989
# 303990
# 303993
# 303994
# 303995
# 303997
# 303998
# 303999
# 304000
# 304001
# 304002
# 304003
# 304004
# 304005
# 304006
# 304007
# 304008
# 304009
# 304010
# 304011
# 304013
# 304014
# 304015
# 304016
# 304017
# 304022
# 304024
# 304025
# 304029
# 304030
# 304031
# 304032
# 304033
# 304035
# 304038
# 304039
# 304040
# 304042
# 304043
# 304045
# 304046
# 304048
# 304049
# 304050
# 304052
# 304053
# 304056
# 304059
# 304060
# 304061
# 304062
# 304065
# 304066
# 304067
# 304068
# 304069
# 304071
# 304075
# 304076
# ...
